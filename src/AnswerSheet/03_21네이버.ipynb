# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
import json
import pandas as pd

client_id = "FCh4OfftDC5IroX1zpNv"
client_secret = "m2PJX6ySOw"

encText = urllib.parse.quote("삼육대학교")

link_list = []
title_list = []

for temp in range(1,1000,100):
    url = "https://openapi.naver.com/v1/search/blog?query=" + encText +"&display=100&start={0}".format(temp)# JSON 결과
    print(url)
    # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)

    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()

        blogdata = json.loads(response_body)

        for blog_temp in blogdata['items']:
            link = blog_temp['link'].replace('blog','m.blog')
            title = blog_temp['title']
            link_list.append(link)
            title_list.append(title)


    else:
        print("Error Code:" + rescode)

df = pd.DataFrame({'제목':title_list,'주소':link_list})
# Out:
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%9C%A1%EB%8C%80%ED%95%99%EA%B5%90&display=100&start=1
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%9C%A1%EB%8C%80%ED%95%99%EA%B5%90&display=100&start=101
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%9C%A1%EB%8C%80%ED%95%99%EA%B5%90&display=100&start=201
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%9C%A1%EB%8C%80%ED%95%99%EA%B5%90&display=100&start=301
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%9C%A1%EB%8C%80%ED%95%99%EA%B5%90&display=100&start=401
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%9C%A1%EB%8C%80%ED%95%99%EA%B5%90&display=100&start=501
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%9C%A1%EB%8C%80%ED%95%99%EA%B5%90&display=100&start=601
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%9C%A1%EB%8C%80%ED%95%99%EA%B5%90&display=100&start=701
# ...

# %%
df.to_csv('네이버블로그. csv')

# %%
import pandas as pd

df = pd.DataFrame({'link':link_list,'description':des_list})
df
# Out:
#                                                 link  \
# 0      https://blog.naver.com/pih870318/223370758588
# 1       https://blog.naver.com/bahnsoon/223381305663
# 2                    https://zomzom.tistory.com/6224
# 3        https://blog.naver.com/obh1680/223299259449
# 4       https://blog.naver.com/bom25bom/223213753359
# ..                                               ...
# 995      https://blog.naver.com/pinknwo/222670601304
# 996    https://blog.naver.com/yacht1025/222862628021
# 997  https://blog.naver.com/crazyxinxin/223329508978
# 998     https://blog.naver.com/gofl9387/223117003606
# 999  https://blog.naver.com/daramjoohee/221339231008
#
#                                            description
# 0    <b>제주도</b> 카페 최대 규모 <b>스타벅스</b> 더제주송당파크R점 한정메뉴...
# 1    <b>제주 도</b>토리숲에서 나온 뒤로는 바로 옆 송당 <b>스타벅스</b>로 향...
# 2    <b>제주도</b>에는 <b>제주도</b> <b>스타벅스</b>에서만 판매하는 메뉴...
# 3    위치 주소 : <b>제주도</b> 제주시 구좌읍 비자림로 1197 전화번호 : 15...
# ...

# %%
df.to_csv('네이버-스타벅스.csv')

# %%
# 네이버 검색 API 예제 -  카페 검색
import os
import sys
import urllib.request
import json

client_id = "FCh4OfftDC5IroX1zpNv"
client_secret = "m2PJX6ySOw"

encText = urllib.parse.quote("스타벅스+제주도")

link_list = []
des_list = []

for temp in range(1,1000,100):
    url = "https://openapi.naver.com/v1/search/cafearticle?query=" + encText +"&display=100&start={0}".format(temp)# JSON 결과
    print(url)
    # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)

    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()

        cafedata = json.loads(response_body)

        for cafe_temp in cafedata['items']:
            link = cafe_temp['link']
            des = cafe_temp['description']
            link_list.append(link)
            des_list.append(des)


    else:
        print("Error Code:" + rescode)
# Out:
# https://openapi.naver.com/v1/search/cafearticle?query=%EC%8A%A4%ED%83%80%EB%B2%85%EC%8A%A4%2B%EC%A0%9C%EC%A3%BC%EB%8F%84&display=100&start=1
# https://openapi.naver.com/v1/search/cafearticle?query=%EC%8A%A4%ED%83%80%EB%B2%85%EC%8A%A4%2B%EC%A0%9C%EC%A3%BC%EB%8F%84&display=100&start=101
# https://openapi.naver.com/v1/search/cafearticle?query=%EC%8A%A4%ED%83%80%EB%B2%85%EC%8A%A4%2B%EC%A0%9C%EC%A3%BC%EB%8F%84&display=100&start=201
# https://openapi.naver.com/v1/search/cafearticle?query=%EC%8A%A4%ED%83%80%EB%B2%85%EC%8A%A4%2B%EC%A0%9C%EC%A3%BC%EB%8F%84&display=100&start=301
# https://openapi.naver.com/v1/search/cafearticle?query=%EC%8A%A4%ED%83%80%EB%B2%85%EC%8A%A4%2B%EC%A0%9C%EC%A3%BC%EB%8F%84&display=100&start=401
# https://openapi.naver.com/v1/search/cafearticle?query=%EC%8A%A4%ED%83%80%EB%B2%85%EC%8A%A4%2B%EC%A0%9C%EC%A3%BC%EB%8F%84&display=100&start=501
# ...

# %%
des_list
# Out:
# ['좀 둘러보니 대기업이 들어오는게 견제가 되고 있는거군요. ㅎㅎㅎ <b>제주도</b> 향토음식이 아니라면 그냥 서울맛집에서 먹는게 돈도 마음도 지킬 수 있겠군여 ㅠㅠ <b>스타벅스</b>를 가는이유는 적어도 지뢰를 밟지는 않아서 입니다.',
#  '해녀 스노우 볼/ 리유저블 컵 / 티스푼 /키링 / 에코백 등등 이것들이 <b>제주도</b>의 특산 스벅. MD들이래요! 오전은 <b>스타벅스</b>에서 시작해요 ~ <b>스타벅스</b>가 곳곳에 많고, DT 점도 많네요 ! 오늘 비가 온다는 소식이 있어서 날씨... ',
#  '<b>제주도</b>에서도 <b>스타벅스</b>!! 커피를 또 워낙 좋아하는 저인지라 제주에서 그리고 우리나라에서 젤 크다는 <b>스타벅스</b>를 그냥 지나칠수가 없겠더라구요. 비가 오는 며칠전 ~~다녀왔어요 !! 제주 떠오르는 핫플레이스답게... ',
#  '개인거래(판매), 판매중, 가격 2,222원, 직접결제(네이버페이 송금), <b>스타벅스</b> <b>제주도</b> 한정 한라봉MD 사다드려요!, 오늘 출시된 한라봉 엠디!!! 너무 갖고 싶은데 못 온다하시는 분들... ',
#  '<b>제주도</b> <b>스타벅스</b>에는 <b>제주도</b>에서만 파는 한정메뉴가 몇개있어요~ 어제 오늘 신랑과 저 각각 하나씩, 총 4개의 한정메뉴를 마셔봤습니다ㅋ 어제 마신 쑥떡크림프라푸치노와 천혜향 블랙 티 블렌디드 쑥떡 크림은 많이 달지... ',
#  '확인해보니 쑥떡크림이 제일 칼로리가 높더라구요 그래서 맛있구나 ^^;ㅋㅋ 흑임자 프라푸치노도 있었는데, 나중에 <b>제주도</b> <b>스타벅스</b> 들르셔서 제주only메뉴를 드실 기회가 생긴다면, 과일이 들어간 음료보다는 쑥/흑임자... ',
# ...

# %%
def naver_blog(sdata):
    import os
    import sys
    import urllib.request
    import json

    client_id = "FCh4OfftDC5IroX1zpNv"
    client_secret = "m2PJX6ySOw"

    encText = urllib.parse.quote(sdata)

    link_list = []
    des_list = []

    for temp in range(1,1000,100):
        url = "https://openapi.naver.com/v1/search/blog?query=" + encText +"&display=100&start={0}".format(temp)# JSON 결과
        print(url)
        # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
        request = urllib.request.Request(url)
        request.add_header("X-Naver-Client-Id",client_id)
        request.add_header("X-Naver-Client-Secret",client_secret)
        response = urllib.request.urlopen(request)

        rescode = response.getcode()
        if(rescode==200):
            response_body = response.read()

            blogdata = json.loads(response_body)

            for blog_temp in blogdata['items']:
                link = blog_temp['link']
                des = blog_temp['description']
                link_list.append(link)
                des_list.append(des)


        else:
            print("Error Code:" + rescode)


    import pandas as pd

    df = pd.DataFrame({'link':link_list,'description':des_list})
    df.to_csv(sdata+".csv")

# %%
naver_blog('삼육대학교')
# Out:
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%9C%A1%EB%8C%80%ED%95%99%EA%B5%90&display=100&start=1
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%9C%A1%EB%8C%80%ED%95%99%EA%B5%90&display=100&start=101
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%9C%A1%EB%8C%80%ED%95%99%EA%B5%90&display=100&start=201
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%9C%A1%EB%8C%80%ED%95%99%EA%B5%90&display=100&start=301
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%9C%A1%EB%8C%80%ED%95%99%EA%B5%90&display=100&start=401
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%9C%A1%EB%8C%80%ED%95%99%EA%B5%90&display=100&start=501
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%9C%A1%EB%8C%80%ED%95%99%EA%B5%90&display=100&start=601
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%9C%A1%EB%8C%80%ED%95%99%EA%B5%90&display=100&start=701
# ...

# %%
from tqdm import tqdm
data = ['a','b','c','d']
str_result = ''
for temp in tqdm(data):
    str_result += temp

str_result
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 29177.77it/s]
# 'abcd'
